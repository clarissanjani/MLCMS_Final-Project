# %% [markdown]
# ## Runge-Kutta method for a generic function

# %%
from src.integration import *
from src.model import *
import matplotlib.pyplot as plt

# %% [markdown]
# ## Runge-Kutta method for SIR

# %%
t_0 = 0
t_end = 200

beta=11.5
A=20
d=0.1
nu=1
b=0.022
mu0 = 10      
mu1 = 10.45
y0 = [195.3, 0.052, 4.4]

t = np.linspace(t_0, t_end, 3000)

model = SIR(t_0, t_end, beta, A, d, nu, b, mu0, mu1)

s, i, r = classic_runge_kutta(model.integration_model, y0, t)

plt.plot(s, i);

# %%
t
# Out:
# array([0.00000000e+00, 6.66888963e-02, 1.33377793e-01, ...,
#        1.99866622e+02, 1.99933311e+02, 2.00000000e+02])

# %%
h = t[1]-t[0]

# %%
testa = np.array([1, 2, 3])

# %%
(h/2)*testa
# Out:
# array([0.03334445, 0.0666889 , 0.10003334])
